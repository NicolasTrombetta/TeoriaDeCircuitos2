# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo semanal 2
# #### Autor:Nicolas Trombetta
# #### Profesor: Mariano Llamedo Soria

# %% [markdown]
# Queremos hallar la función transferencia pasa bajos mediante aproximación de máxima planicidad, por caso, Butterworth, de orden 6.
# Para ello planteamos:
# \begin{equation}
# |T(jw)|^2=T(s) T^*(s)=\frac{1}{1+w^{12}}
# \end{equation}
# Reemplazado $w=\frac{s}{j}$
# \begin{equation}
# |T(S)|^2=\frac{1}{1+S^{12}}
# \end{equation}
# Entonces queremos hallar los polos,para ello resolvemos:
# \begin{equation}
# S^{12}=-1
# \end{equation}
#
# \begin{equation}
# (|S|e^{j arg(S)})^{12}=1e^{j(2k+1)\pi}
# \end{equation}
#
# Finalmente se obtiene que los polos se encuentran en:
# \begin{equation}
# |S|=1
# \end{equation}
# \begin{equation}
# arg(s)=\frac{(2k+1)\pi}{12};k=0,1,2,..,11;
# \end{equation}
# Para hallar la funcion transferencia descartamos los polos que no nos interesan, es decir, los que estan del lado derecho del eje $jw$
# \begin{equation}
# T(S)=\frac{1}{\prod_{k=3}^{8} (S-1e^{\frac{j(2k+1)\pi}{12}})}
# \end{equation}
#
# Agrupando nos queda:
# \begin{equation}
# T(S)=\frac{1}{(S^2-S2cos(\frac{7}{12}\pi)+1)}\frac{1}{(S^2-S2cos(\frac{9}{12}\pi)+1)}\frac{1}{(S^2-S2cos(\frac{11}{12}\pi)+1)}
# \end{equation}
#
# Para el grafico del modulo nos ayudamos de los tres puntos que quedan fijos en un Butterworth,es decir:
# $$ T(\omega=0)=1 \qquad T(\omega=1)=\frac{\sqrt{2}}{2} \qquad T(\omega=\infty)=0 $$
# ![image.png](attachment:3c74c8a7-57da-4a2d-8c23-006b0d291bed.png)
#
# y el grafico de la fase queda:
# $$
# \theta(\omega)=-arctan(\frac{-2\omega cos(\frac{7}{12}\pi)}{1-\omega^2})-arctan(\frac{-2\omega cos(\frac{9}{12}\pi)}{1-\omega^2})-arctan(\frac{-2\omega cos(\frac{11}{12}\pi)}{1-\omega^2})
# $$
# Evaluamos en los siguientes puntos:
# $$
# \omega \rightarrow \infty ; \theta(\omega)\rightarrow -3\pi
# $$
# $$
# \omega = 0 ; \theta(\omega)=0
# $$
#
# $$
# \omega = 1 ; \theta(\omega)=\frac{-3\pi}{2}
# $$
#
# ![image.png](attachment:c66e741f-c92b-4f9a-bd88-4a6491fe6a7b.png)

# %% [markdown]
# ### Implementacion de la red
# Dividimos la red en transferencias de SOS agrupando los polos complejos conjugados y calculamos los distintos factores de calidad(Q),tomando $w_0=1$:
# \begin{equation}
#     Q_1=-\frac{1}{2cos(\frac{11 \pi}{12})}=0.5176
# \end{equation}
# \begin{equation}
#     Q_2=-\frac{1}{2cos(\frac{9 \pi}{12})}=0.707
# \end{equation}
# \begin{equation}
#     Q_3=-\frac{1}{2cos(\frac{7 \pi}{12})}=1.932
# \end{equation}
#
# #### Primer SOS: Sallen-Key
# ![image.png](attachment:786a7af1-2d9d-45f5-a446-4797454fec53.png)
#
# Planteamos las ecuaciones utilizando metodo de nudos:
# \begin{equation}
# V_A(G_1+G_2+SC_2)-V_iG_1-V_oSC_2-V_BG2=0
# \end{equation}
# \begin{equation}
# V_B(G_2+SC_1)-V_AG_2=0
# \end{equation}
# \begin{equation}
# V_B(G_3+G_4)-V_oG_4=0
# \end{equation}
# Escribimos las matrices para poder resolver por metodo de cramer:
#
# $$
# \begin{bmatrix}
# SC_2+G1+G2 & -G2 & -SC2\\
# -G2 & SC_1+G2 & 0 \\
#  0 & G_4+G_3 & -G4
# \end{bmatrix}
# \begin{bmatrix}
# VA \\VB \\ VO
# \end{bmatrix}
# =
# \begin{bmatrix}
# V_iG_1\\0\\0
# \end{bmatrix}
# $$
# Calculomos $V_o$:
# $$
# V_o=\frac{
# \begin{vmatrix}
#     SC_2+G1+G2 & -G2 & V_iG_1\\
#     -G2 & SC_1+G2 & 0 \\
#  0 & G_4+G_3 & 0
# \end{vmatrix}
# }
# {
# \begin{vmatrix}
# SC_2+G1+G2 & -G2 & -SC2\\
# -G2 & SC_1+G2 & 0 \\
#  0 & G_4+G_3 & -G4
#  \end{vmatrix}
# }
# = \frac{-V_iG_1G_2(G_4+G_3)}{-C_1C_2G_4S^2+S[G_2C_2(G_4+G_3)-G_4C_1(G_1+G_2)]+{G_2}^2G_4}
# $$
#
# La transferencia nos queda:
#
# $$
# \frac{V_o}{V_i} = \frac{(G_3+G_4)}{G_4}\frac{\frac{G_1G_2}{C_1C_2}}{S^2+S[\frac{(G_1+G_2)}{C_2}-\frac{G_2G_3}{G_4C_1}]+\frac{G_2G_1}{C_2C_1}}
# $$
# Obligamos a que  $\frac{(G_3+G_4)}{G_4}=1$, entonces $G_3=0$
# $$
# \frac{V_o}{V_i} = \frac{\frac{G_1G_2}{C_1C_2}}{S^2+S[\frac{(G_1+G_2)}{C_2}]+\frac{G_2G_1}{C_2C_1}}
# $$
#
# Donde:
# $$
#     {\omega_0}^2=\frac{G_1G_2}{C_1C_2}
# $$
# $$
#     \frac{\omega_0}{Q_1}=\frac{(G_1+G_2)}{C_2}
# $$
# Para tener dos grados de libertad, tomamos $G_1=G_2$ y normalizamos con $\Omega_z=G_1$ y $\Omega_\omega=\sqrt{\frac{G_1G_2}{C_1C_2}}$. Entonces:
# $$
# C_1C_2=1
# $$
# $$
# 2Q_1=C_2
# $$
#
# ![image.png](attachment:1e441614-dd3d-497e-a53d-9683bfef9451.png)

# %%
import sympy as sp
from IPython.display import display, Math

#Utilizo sympy para verficar que la transferecia este bien calculada

S,G1,G2,G3,G4,C1,C2=sp.symbols('S G1 G2 G3 G4 C1 C2')
VA,VB,Vi,Vo=sp.symbols('VA,VB,Vi,Vo')

eqs=[
    VA*(G1+G2+S*C2)-Vi*(G1)-Vo*S*C2-VB*G2,
    VB*(G2+S*C1)-VA*G2,
    VB*(G3+G4)-Vo*G4,
]

sol=sp.solve(eqs,[VA,VB,Vo])

T1 = sp.simplify(sol[Vo]/Vi)

display(Math("T1 = " + sp.latex(T1)))
# Out:
# $\displaystyle T1 = \frac{G_{1} G_{2} \left(G_{3} + G_{4}\right)}{C_{1} C_{2} G_{4} S^{2} + C_{1} G_{1} G_{4} S + C_{1} G_{2} G_{4} S - C_{2} G_{2} G_{3} S + G_{1} G_{2} G_{4}}$

# %% [markdown]
# #### Segundo SOS: KHN
# ![image.png](attachment:b16b8032-0d74-44e0-9c24-ce0284283966.png)
#
# Planteamos las ecuaciones utilizando metodo de nudos:
# \begin{equation}
#     V_A(G_1+G_2+G_3)-V_iG_1-V_oG_2-V_1G_3=0
# \end{equation}
# \begin{equation}
#     V_A(G_6+G_7)-V_2G_6=0
# \end{equation}
# \begin{equation}
#     V_oSC_2+V_2G_5=0
# \end{equation}
# \begin{equation}
#     V_2SC_1+V_1G_4=0
# \end{equation}
#
# Resolviendo por sustitucion nos queda:
# $$
# T_2(S)=\frac{-G_1}{G_2}\frac{\frac{G_2G_4G_5}{C_1C_2G_3}}{S^2+S\frac{G_6G_4(G_1+G_2+G_3)}{C_1G_3(G_6+G_7)}+\frac{G_2G_4G_5}{C_1C_2G_3}}
# $$
#
# Donde:
# $$
#     {\omega_0}^2=\frac{G_2G_4G_5}{C_1C_2G_3}
# $$
# $$
#     \frac{\omega_0}{Q_2}=\frac{G_6G_4(G_1+G_2+G_3)}{C_1G_3(G_6+G_7)}
# $$
# Para tener dos grados de libertad, tomamos $G_1=G_2=G_3=G_4=G_5=G_7$ y $C_1=C_2=C$ y normalizamos con $\Omega_z=G_1$ y $\Omega_\omega=\sqrt{\frac{G_2G_4G_5}{C_1C_2G_3} }$ Entonces:
# $$
# C^2=1  \rightarrow C=1
# $$
# $$
# Q_2=\frac{G_6+1}{3G_6} \rightarrow G_6=\frac{1}{3Q_2-1}
# $$
#
#
# ![image.png](attachment:a2bbe373-8ee8-4e44-9416-261fc1d94979.png)

# %%
import sympy as sp
from IPython.display import display, Math

#Utilizo sympy para verficar que la transferecia este bien calculada

S,G1,G2,G3,G4,G5,G6,G7,C1,C2=sp.symbols('S G1 G2 G3 G4 G5 G6 G7 C1 C2')
VA,V2,V1,Vi,Vo=sp.symbols('VA,V2,V1,Vi,Vo')

eqs=[
    VA*(G1+G2+G3)-Vi*(G1)-Vo*G2-V1*G3,
    VA*(G6+G7)-V2*G6,
    Vo*S*C2+V2*G5,
    V2*S*C1+V1*G4
]

sol=sp.solve(eqs,[VA,V1,V2,Vo])

T2 = sp.simplify(sol[Vo]/Vi)

display(Math("T2 = " + sp.latex(T2)))
# Out:
# $\displaystyle T2 = \frac{G_{1} G_{4} G_{5} \left(- G_{6} - G_{7}\right)}{C_{1} C_{2} G_{3} G_{6} S^{2} + C_{1} C_{2} G_{3} G_{7} S^{2} + C_{2} G_{1} G_{4} G_{6} S + C_{2} G_{2} G_{4} G_{6} S + C_{2} G_{3} G_{4} G_{6} S + G_{2} G_{4} G_{5} G_{6} + G_{2} G_{4} G_{5} G_{7}}$

# %% [markdown]
# #### Tercer SOS:Multiple Feedback
# ![image.png](attachment:bb4cdcab-dbf9-4d21-8993-4cb42c7515a6.png)
#
# Planteamos las ecuaciones utilizando metodo de nudos:
# \begin{equation}
# V_A(G_1+G_2+G_3+SC_1)-V_iG_3-V_oG_1=0
# \end{equation}
#
# \begin{equation}
# V_oSC_2+V_AG_2=0
# \end{equation}
#
# Resolviendo nos queda:
# $$
# T_3(S)= \frac{-G_3}{G_1}\frac{\frac{G_1G_2}{C_1C_2}}{S^2+S\frac{(G_1+G_2+G_3)}{C_1}+\frac{G_1G_2}{C_1C_2}}
# $$
#
# Donde:
# $$
#     {\omega_0}^2=\frac{G_1G_2}{C_1C_2}
# $$
# $$
#     \frac{\omega_0}{Q_3}=\frac{(G_1+G_2+G_3)}{C_1}
# $$
# Para tener dos grados de libertad, tomamos $G_1=G_2=G_3$  y normalizamos con $\Omega_z=G_1$ y $\Omega_\omega=\sqrt{\frac{G_1G_2}{C_1C_2} }$. Entonces:
# $$
# C_1C_2=1
# $$
# $$
# Q_3=\frac{C_1}{3} \rightarrow C_1=3Q_3
# $$
#
# ![image.png](attachment:e51e1104-536d-4862-bdcf-a4de7f348bf2.png)

# %%
import sympy as sp
from IPython.display import display, Math

#Utilizo sympy para verficar que la transferecia este bien calculada

S,G1,G2,G3,C1,C2=sp.symbols('S G1 G2 G3 C1 C2')
VA,Vi,Vo=sp.symbols('VA,Vi,Vo')

eqs=[
    VA*(G1+G2+G3+S*C1)-Vi*G3-Vo*G1,
    Vo*S*C2+VA*G2
]

sol=sp.solve(eqs,[VA,Vo])

T3 = sp.simplify(sol[Vo]/Vi)

display(Math("T3 = " + sp.latex(T3)))
# Out:
# $\displaystyle T3 = - \frac{G_{2} G_{3}}{C_{1} C_{2} S^{2} + C_{2} G_{1} S + C_{2} G_{2} S + C_{2} G_{3} S + G_{1} G_{2}}$

# %% [markdown]
# ### Simulacion en LTSPICE
# A partir de los circuitos mostrados anteriormente se armo la siguiente red.Para simular se uso la siguiente directiva:ac dec 1000 1m 100
# ![image.png](attachment:407844ef-b3e4-42d1-8bce-36659af26663.png)
#
# ![image.png](attachment:83c14054-418a-496d-af07-fc806cad913a.png)

# %% [markdown]
# Para obtener una ganancia de 10db en la banda de paso hay que modificar la ganancia de una de las redes.Por ejemplo en el KHN la ganancia en la banda de paso es $\frac{G1}{G2}$, entonces la transferencia queda:
# $$
# T_2(S)=\frac{-G_1}{G_2}\frac{\frac{G_2G_4G_5}{C_1C_2G_3}}{S^2+S\frac{G_6G_4(G_1+G_2+G_3)}{C_1G_3(G_6+G_7)}+\frac{G_2G_4G_5}{C_1C_2G_3}}
# $$
#
# Donde:
# $$
#     {\omega_0}^2=\frac{G_2G_4G_5}{C_1C_2G_3}
# $$
# $$
#     \frac{\omega_0}{Q_2}=\frac{G_6G_4(G_1+G_2+G_3)}{C_1G_3(G_6+G_7)}
# $$
# como $G_1=3,1622G_2$ y ademas tomamos $G_2=G_3=G_4=G_5=G_7$ y $C_1=C_2=C$ y normalizamos con $\Omega_z=G_2$ y $\Omega_\omega=\sqrt{\frac{G_2G_4G_5}{C_1C_2G_3} }$ Entonces:
# $$
# C^2=1  \rightarrow C=1
# $$
# $$
# Q_2=\frac{G_6+1}{5.16G_6} \rightarrow G_6=\frac{1}{5.16Q_2-1}
# $$
#
# A continuacion se muestra la simulacion en Ltspice con estos cambios:
# ![image.png](attachment:29d4ae2c-db84-4cf1-8868-f02eb10ba7e7.png)

# %% [markdown]
# #### Conclusion
# Logramos implementar un filtro de máxima planicidad de orden 6 a partir de la cascada de tres secciones de segundo orden (SOS) propuestas. Además, verificamos que las funciones de transferencia fueron correctamente obtenidas mediante SymPy, y simulamos la red en LTspice para validar su comportamiento.
#
# Los resultados de simulación muestran una respuesta en frecuencia consistente con la aproximación teórica de máxima planicidad, observándose una banda de paso sin ondulaciones y una atenuación progresiva en la banda de rechazo, tal como se esperaba. Esto confirma tanto la correcta síntesis del filtro como la validez de las aproximaciones y normalizaciones empleadas durante el diseño.
